# %%
import numpy as np
import SimpleITK as sitk
import cv2
import matplotlib.pyplot as plt
import os

# %%
pred = sitk.ReadImage("./pred/1.png")
pred = sitk.GetArrayFromImage(pred)
print(pred.shape)
print(set(pred.flatten()))
# Out:
# (256, 256)
# {0, 1, 2}

# %%
gt = sitk.ReadImage("./gt/1.png")
gt = sitk.GetArrayFromImage(gt)
print(gt.shape)
print(set(gt.flatten()))
# Out:
# (256, 256)
# {0, 1, 2}

# %%
plt.imshow(pred)

# %%
plt.imshow(gt)
